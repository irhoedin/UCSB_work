# %%
# %matplotlib inline
reload(gpib)
# Out:
# <module 'gpib' from 'gpib.py'>

# %%
# Out:
# KEITHLEY INSTRUMENTS INC.,MODEL 2400,1386470,C32   Oct  4 2010 14:20:11/A02  /S/K
#
# 2400 confirmed

# %%
# %matplotlib inline
import gpib
reload(gpib)
path = '/Users/nakayamahidenori/my_python_modules/GPIB connection test'
k2400 = gpib.KE2400('GPIB::13::INSTR')
df = k2400.iv_sweep(path, 'test1', -1, 1, .01)
# Out:
# KEITHLEY INSTRUMENTS INC.,MODEL 2400,1386470,C32   Oct  4 2010 14:20:11/A02  /S/K
#
# 2400 confirmed
# Hey! "test1" alrady exists in this directory!!
# Enter a new name: test2
# Hey! "test2" alrady exists in this directory!!
# Enter a new name: test3
# "test3" is an unique filename!
# est. scan time = 1 [s]
# scan completed
#     Voltage   Current    Registance      Time   Status
# 0      -1.0 -0.060669  9.910000e+37  2476.191  21508.0
# 1      -0.9 -0.054608  9.910000e+37  2476.250  21508.0
# 2      -0.8 -0.048599  9.910000e+37  2476.309  21508.0
# 3      -0.7 -0.042535  9.910000e+37  2476.367  21508.0
# 4      -0.6 -0.036492  9.910000e+37  2476.426  21508.0
# 5      -0.5 -0.030422  9.910000e+37  2476.484  21508.0
# 6      -0.4 -0.024357  9.910000e+37  2476.543  21508.0
# 7      -0.3 -0.018284  9.910000e+37  2476.602  21508.0
# 8      -0.2 -0.012191  9.910000e+37  2476.660  21508.0
# 9      -0.1 -0.006097  9.910000e+37  2476.781  21508.0
# ...

# %%
# %matplotlib inline
import gpib
reload(gpib)
path = '/Users/nakayamahidenori/my_python_modules/GPIB connection test'
k2400 = gpib.KE2400('GPIB::13::INSTR')
df = k2400.iv_sweep(path, 'test6', -1, 1, .01)
# Out:
# KEITHLEY INSTRUMENTS INC.,MODEL 2400,1386470,C32   Oct  4 2010 14:20:11/A02  /S/K
#
# 2400 confirmed
# Hey! "test6" alrady exists in this directory!!
# Enter a new name: ttt
# "ttt" is an unique filename!
# est. scan time = 11 [s]
# scan completed
# ---------------------------------------------------------------------------
# VisaIOError                               Traceback (most recent call last)
# <ipython-input-5-5813812e1e5f> in <module>()
#       4 path = '/Users/nakayamahidenori/my_python_modules/GPIB connection test'
#       5 k2400 = gpib.KE2400('GPIB::13::INSTR')
# ----> 6 df = k2400.iv_sweep(path, 'test6', -1, 1, .01)
#
# /Users/nakayamahidenori/my_python_modules/gpib.pyc in iv_sweep(self, path, filename, v_start, v_end, v_step, sdel, cmpl, nplc, graph)
#     183         path_file, filename = self.confirm_unique_name(path, filename)
#     184
# --> 185         buffer_out = self.iv_sweep_core(v_start, v_end, v_step)
# ...

# %%
print k2400.timeout
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-0ee2a125ad24> in <module>()
# ----> 1 print k2400.timeout
#
# AttributeError: 'KE2400' object has no attribute 'timeout'

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# %matplotlib nbagg

# %%
reload(gpib)
path = '/Users/nakayamahidenori/my_python_modules/GPIB connection test'
k2400 = gpib.KE2400('GPIB::13::INSTR')
a = k2400.realtime_current(path, 'rc8', 0.01, freq=2., duration=10.)
# Out:
# KEITHLEY INSTRUMENTS INC.,MODEL 2400,1386470,C32   Oct  4 2010 14:20:11/A02  /S/K
#
# 2400 confirmed
# "rc8" is an unique filename!
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">

# %%
reload(gpib)
path = '/Users/nakayamahidenori/my_python_modules/GPIB connection test'
k2400 = gpib.KE2400('GPIB::13::INSTR')
a = k2400.v_sweep(path, 'vsweep3', 0.001, 5, 10)
# Out:
# KEITHLEY INSTRUMENTS INC.,MODEL 2400,1386470,C32   Oct  4 2010 14:20:11/A02  /S/K
#
# 2400 confirmed
# Hey! "vsweep3" alrady exists in this directory!!
# Enter a new name: v15
# "v15" is an unique filename!
# est. scan time = 50 [s]
# scan completed
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">

# %%
print a
# Out:
#     Voltage  Current    Registance      Time   Status
# 0  0.016629    0.001  9.910000e+37  883.4775  39940.0
# 1  0.016628    0.001  9.910000e+37  893.5059  39940.0
# 2  0.016623    0.001  9.910000e+37  903.5332  39940.0
# 3  0.016630    0.001  9.910000e+37  913.5615  39940.0
# 4  0.016649    0.001  9.910000e+37  923.5889  39940.0

# %%
# %matplotlib inline
import gpib
reload(gpib)
path = '/Users/nakayamahidenori/my_python_modules/GPIB connection test'
k2400 = gpib.KE2400('GPIB::13::INSTR')
# Out:
# KEITHLEY INSTRUMENTS INC.,MODEL 2400,1386470,C32   Oct  4 2010 14:20:11/A02  /S/K
#
# 2400 confirmed

# %%
df = k2400.iv_sweep(path, 'test1', -1, 1, .01)
print df
# Out:
# Hey! "test1" alrady exists in this directory!!
# Enter a new name: 170104_1
# "170104_1" is an unique filename!
# est. scan time = 11 [s]
#      Voltage       Current    Registance      Time   Status
# 0      -1.00 -3.022402e-08  9.910000e+37  66679.86  21508.0
# 1      -0.99  2.419839e-08  9.910000e+37  66679.91  21508.0
# 2      -0.98 -2.142901e-08  9.910000e+37  66679.96  21508.0
# 3      -0.97  1.513218e-08  9.910000e+37  66680.02  21508.0
# 4      -0.96  1.942349e-08  9.910000e+37  66680.07  21508.0
# 5      -0.95 -2.643499e-08  9.910000e+37  66680.12  21508.0
# 6      -0.94  2.179511e-08  9.910000e+37  66680.17  21508.0
# 7      -0.93 -2.853632e-08  9.910000e+37  66680.22  21508.0
# 8      -0.92  4.332307e-09  9.910000e+37  66680.28  21508.0
# 9      -0.91 -2.311628e-09  9.910000e+37  66680.33  21508.0
# 10     -0.90 -3.759398e-09  9.910000e+37  66680.38  21508.0
# 11     -0.89  1.070123e-08  9.910000e+37  66680.44  21508.0
# ...

# %% [markdown]
# $\frac{1}{2}$
