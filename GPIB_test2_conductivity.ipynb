# %%
import gpib

# %%
gpib1 = 'GPIB0::12::INSTR'
gpib2 = 'GPIB0::13::INSTR'
# Out:
# 6220 confirmed
# 2400 confirmed

# %%
# %matplotlib inline
reload(gpib)
cnd = gpib.Conductivity(gpib1,gpib2)
path = '/Users/nakayamahidenori/my_python_modules/GPIB connection test'
filename = 'cnd1'
r, df = cnd.measure(path, 'cnd3', sour_del=.1)
# Out:
# 6220 confirmed
# 2400 confirmed
# Hey! "cnd3" alrady exists in this directory!!
# Enter a new name: cnd5
# "cnd5" is an unique filename!
# est. meas time : 22 [s]
# R = 4.97e+00 [Ohm]

# %%
r, df = cnd.measure(path, 'cnd3', sour_del=.1)
# Out:
# Hey! "cnd3" alrady exists in this directory!!
# Enter a new name: cnd6
# "cnd6" is an unique filename!
# est. meas time : 3 [s]
# R = 4.94e+00 [Ohm]

# %%
r, df = cnd.measure(path, 'cnd3', sour_del=.01)
# Out:
# Hey! "cnd3" alrady exists in this directory!!
# Enter a new name: cnd7
# "cnd7" is an unique filename!
# est. meas time : 1 [s]
# R = 4.96e+00 [Ohm]

# %%
r, df = cnd.measure(path, 'cnd3', sour_del=.001)
# Out:
# Hey! "cnd3" alrady exists in this directory!!
# Enter a new name: cnd8
# "cnd8" is an unique filename!
# est. meas time : 1 [s]
# R = 4.96e+00 [Ohm]
