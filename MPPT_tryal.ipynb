# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib nbagg

# %%
import gpib

# %%
smu = gpib.KE2602()
# Out:
# Keithley Instruments Inc., Model 2602, 1083453, 1.4.2
#
# 2602 confirmed

# %%
smu.mppt('test')
# Out:
# <img src="data:image/png;base64,...">
# Interrupted
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1

# %%
smu.meas_iv('','test3', v_end=-0.5)
# Out:
# "test3" is an unique filename!
# Foward scan
# Voc: 0.83 [V],Jsc: 5.61 [mA/cm2],FF: 0.53 [-],PCE: 2.47 [%],Rs: 686.93 [Ohm/cm2],Rsh: 887.79 [Ohm/cm2]
# Rerverse scan
# Voc: 0.76 [V],Jsc: 5.36 [mA/cm2],FF: 0.47 [-],PCE: 1.94 [%],Rs: 819.24 [Ohm/cm2],Rsh: 595.07 [Ohm/cm2]
# <img src="data:image/png;base64,...">
#      v_foward   j_foward  v_reverse  j_reverse
# 0        1.30  69.713194      -0.50  -6.051991
# 1        1.29  58.243981      -0.49  -6.075671
# 2        1.28  51.518287      -0.48  -6.062153
# 3        1.27  46.736574      -0.47  -6.049676
# 4        1.26  42.996759      -0.46  -6.040833
# 5        1.25  39.932870      -0.45  -6.031944
# 6        1.24  37.278704      -0.44  -6.009931
# 7        1.23  34.930556      -0.43  -5.999306
# 8        1.22  32.811574      -0.42  -5.974560
# 9        1.21  30.847917      -0.41  -5.949699
# 10       1.20  29.034028      -0.40  -5.963519
# 11       1.19  27.364120      -0.39  -5.934329
# 12       1.18  25.790046      -0.38  -5.901528
# ...

# %%
a = smu.mppt('test4_mppt')
# Out:
# here
# <img src="data:image/png;base64,...">
# Interrupted
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1

# %%
a = smu.mppt('test5_mppt', start_v=.55, v_step=0.001)
# Out:
# here
# <img src="data:image/png;base64,...">
# Interrupted
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
