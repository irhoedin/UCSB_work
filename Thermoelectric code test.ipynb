# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib nbagg
import gpib

# %%
reload(gpib)
te = gpib.SeebeckFast()
# Out:
# 2400 confirmed
# 3644 confirmed
# 1529 confirmed
# wait enough for themometer setup

# %%
path = '/Users/nakayamahidenori/my_python_modules/GPIB connection test'
t = te.measure(path,'Seebeck_test01',1., 5.)
# Out:
# "Seebeck_test01" is an unique filename!
# <img src="data:image/png;base64,...">
# Switch the polarity of DC power and hit Enter!
# The Seebeck coefficient is -2.25e-04 [K/V]

# %%
a = 12.001
print '%0.0f' %a
# Out:
# 12

# %%
import time
time.now
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-ec7078a56eca> in <module>()
#       1 import time
# ----> 2 time.now
#
# AttributeError: 'module' object has no attribute 'now'

# %%
a = [[1,2,3],[3,4,5],[6,7,8]]

# %%
pd.DataFrame(a)
# Out:
#    0  1  2
# 0  1  2  3
# 1  3  4  5
# 2  6  7  8

# %%
int(32.3)
# Out:
# 32

# %%
import datetime
print datetime.datetime.now()
# Out:
# 2017-01-19 15:10:06.570143

# %%
from import_all import *
f, ax = plt.subplots(1,2, figsize=(10,5))
ax[0].plot([1,2, 3], [2,3, 3], c='blue')
ax[0].yaxis.label.set_color('red')
ax[0].set_ylabel('test')
ax2 = ax[0].twinx()
ax2.plot([1,2, 3], [1.2, 2.3, 1.1])

ax[1].set_title('test')
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,...">

# %%
a = 1.2323e-3
print '%.2e' %a
# Out:
# 1.23e-03
