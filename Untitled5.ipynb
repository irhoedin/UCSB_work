# %%
from import_all import *
from matplotlib import rc
import pylab as pl
rc('text', usetex=True)
pl.rcParams['text.latex.preamble'] = [
    r'\usepackage{tgheros}',  # helvetica font
    r'\usepackage{sansmath}',  # math-font matching  helvetica
    r'\sansmath'  # actually tell tex to use it!
    r'\usepackage{siunitx}',  # micro symbols
    r'\sisetup{detect-all}',  # force siunitx to use the fonts
]

# %%
# %matplotlib inline
pl.figure(1, figsize=(6, 4))
ax = pl.axes([0.1, 0.1, 0.8, 0.7])
t = np.arange(0.0, 1.0 + 0.01, 0.01)
s = np.cos(2 * 2 * np.pi * t) + 2
pl.plot(t, s)

pl.xlabel(r'time$\rm{t}^2$ $\lambda$')
pl.ylabel(r'\textit{voltage (mV)}', fontsize=16)
pl.title(r'\TeX\ Number 1234567890 anisotropic ' +
         r'$\displaystyle\sum_{n=1}^\infty' +
         r'\frac{-e^{i\pi}}{2^n}$' +
         r' and \SI{3}{\micro\metre}', fontsize=16, color='r')

# %%
# %matplotlib inline
from import_all import *
f, ax = plt.subplots(1, figsize=(4,4))
ax.plot(np.linspace(1,3,3), np.linspace(1,10,3))
ax.set_xlabel(r'test $t^2$')

# %% [markdown]
# $\tau_0 = \frac{1}{k_{F} + k_{IC}}$

# %%
# %matplotlib inline
from import_all import *

x = np.linspace(0, 100, 101)
y = x**2

plt.plot(x, y)

# %%
plt.plot(x, y)
plt.yscale('log')
