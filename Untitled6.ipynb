# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib nbagg

# %%
import gpib

# %%
trans = gpib.TFT()
# Out:
# 2400 confirmed
# 6487 confirmed

# %%
reslts = trans.meas_output?

# %%
reslts = trans.meas_output('', 'tft0')
# Out:
# "tft0" is an unique filename!
# <img src="data:image/png;base64,...">
# Interrupted
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
