# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import gpib_nori1 as gpib

# %%
smu = gpib.KE2400()
# Out:
# [u'KEITHLEY INSTRUMENTS INC.,MODEL 2400,1386470,C32   Oct  4 2010 14:20:11/A02  /S/K\n']
# 2400 confirmed

# %%
smu.iv_sweep('','gpibtest', -1., 1., 0.1)
# Out:
# "gpibtest" is an unique filename!
# est. scan time = 1 [s]
# The conductivity is -4.47e-08 [S].
# Section is -9.39e-09 [A]
#     Voltage       Current    Registance      Time   Status
# 0      -1.0  1.388294e-07  9.910000e+37  282.9844  21508.0
# 1      -0.9 -1.406696e-07  9.910000e+37  283.0371  21508.0
# 2      -0.8  1.632625e-07  9.910000e+37  283.0889  21508.0
# 3      -0.7 -1.121470e-07  9.910000e+37  283.1416  21508.0
# 4      -0.6  1.933017e-07  9.910000e+37  283.1953  21508.0
# 5      -0.5 -8.975558e-08  9.910000e+37  283.2471  21508.0
# 6      -0.4  1.830340e-07  9.910000e+37  283.2998  21508.0
# 7      -0.3 -8.814270e-08  9.910000e+37  283.3516  21508.0
# 8      -0.2 -1.789650e-07  9.910000e+37  283.4092  21508.0
# 9      -0.1  7.061633e-08  9.910000e+37  283.4609  21508.0
# 10      0.0  6.100956e-08  9.910000e+37  283.5215  21508.0
# 11      0.1 -1.602640e-07  9.910000e+37  283.5742  21508.0
# 12      0.2  6.478496e-08  9.910000e+37  283.6270  21508.0
# ...

# %%
con = gpib.Conductivity()
# Out:
# KEITHLEY INSTRUMENTS INC.,MODEL 6220,1347935,A05  /700x
#
# KEITHLEY INSTRUMENTS INC.,MODEL 2400,1386470,C32   Oct  4 2010 14:20:11/A02  /S/K
#
# 6220 confirmed
# 2400 confirmed

# %%
con.measure('','gpibtest2')
# Out:
# "gpibtest2" is an unique filename!
# est. meas time : 1 [s]
# R = 1.84e+02 [Ohm]
# (183.78400779220783,
#      Inpt_current   Voltage       Current    Registance      Time   Status
#  0        -0.0010 -0.329215 -1.637204e-12  9.910000e+37  528.6934  39940.0
#  1        -0.0009 -0.305378 -4.246686e-12  9.910000e+37  528.7744  39940.0
#  2        -0.0008 -0.253869 -4.698575e-12  9.910000e+37  528.8555  39940.0
#  3        -0.0007 -0.220329 -4.999806e-12  9.910000e+37  528.9316  39940.0
#  4        -0.0006  0.504141 -1.536979e-12  9.910000e+37  529.2549  39940.0
#  5        -0.0005  0.535992 -1.988562e-12  9.910000e+37  529.3291  39940.0
#  6        -0.0004  0.553013 -3.594250e-12  9.910000e+37  529.4043  39940.0
#  7        -0.0003  0.506142 -5.351206e-12  9.910000e+37  529.4795  39940.0
#  8        -0.0002  0.370252 -1.938227e-12  9.910000e+37  529.5557  39940.0
#  9        -0.0001  0.222454 -8.843343e-13  9.910000e+37  529.6309  39940.0
# ...

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
import gpib_nori1 as gpib
# Out:
# [autoreload of gpib_nori1 failed: Traceback (most recent call last):
#   File "/Users/nakayamahidenori/.pyenv/versions/anaconda-4.0.0/lib/python2.7/site-packages/IPython/extensions/autoreload.py", line 247, in check
#     superreload(m, reload, self.old_objects)
# NameError: name 'smuadr' is not defined
# ]

# %%
tft = gpib.TFT()
# Out:
# KEITHLEY INSTRUMENTS INC.,MODEL 2400,1386470,C32   Oct  4 2010 14:20:11/A02  /S/K
#
# KEITHLEY INSTRUMENTS INC.,MODEL 2400,1246516,C32   Oct  4 2010 14:20:11/A02  /K/K
#
# 2400 confirmed
# 2400 confirmed

# %%
# %matplotlib nbagg
tft.meas_transfer('','tft', nplc=1)
# Out:
# "tft" is an unique filename!
# nplc repeat: 1
# <img src="data:image/png;base64,...">
# Interrupted by user
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1

# %%
a = 12
print 'this {}'.format(a)
# Out:
# this 12
