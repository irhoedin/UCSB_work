# %% [markdown]
# # Training of image process on Python
# Based on http://www.turbare.net/transl/scipy-lecture-notes/advanced/image_processing/index.html

# %%
# %matplotlib inline
from scipy import misc
f = misc.face()
misc.imsave('face.png', f) # uses the Image module (PIL)

import matplotlib.pyplot as plt
plt.imshow(f)
plt.show()

# %%
plt.imshow(f[100:500, :])
