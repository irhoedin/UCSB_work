# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import gpib

# %%
smu = gpib.KE2602()
# Out:
# Keithley Instruments Inc., Model 2602, 1083453, 1.4.2
#
# 2602 confirmed

# %%
# %matplotlib nbagg
smu.meas_tpc('test')
# Out:
# print magic words
#         %load_ext autoreload
#         %autoreload 2
#         %matplotlib nbagg
# <img src="data:image/png;base64,...">
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-298fad4a1f60> in <module>()
#       1 get_ipython().magic(u'matplotlib nbagg')
# ----> 2 smu.meas_tpc('test')
#
# /Users/nakayamahidenori/my_python_modules/gpib.py in meas_tpc(self, filename, area, bias, waittime, nplc, cmpl)
#    1137         df = pd.DataFrame([[.0, .0]], columns=['time', 'current'])
#    1138         while True:
# -> 1139             ax.clear()
#    1140             now = datetime.datetime.now()
#    1141             elasped = now - start_time
#
# /Users/nakayamahidenori/.pyenv/versions/anaconda-4.0.0/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in clear(self)
#    1064     def clear(self):
#    1065         """clear the axes"""
# ...

# %%
smu.meas_light_depen()
# Out:
# 1.1 4.87696e-05
# 1.09 1.33354e-06
# 1.08 -3.65263e-05
# jsc = -19.03 [mA/cm2], Voc = 1.08 [V]
# (-19.027175925925924, 1.08)
